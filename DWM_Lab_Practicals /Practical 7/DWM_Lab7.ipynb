# %% [markdown]
# ## Apriori Algorithm

# %%
dataset = [
    ['milk', 'bread', 'nuts', 'apple'],
    ['milk', 'bread', 'nuts'],
    ['milk', 'bread'],
    ['milk', 'bread', 'apple'],
    ['milk', 'bread', 'apple']
]

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules
import pandas as pd

# Sample dataset
dataset = [
    ['milk', 'bread', 'nuts', 'apple'],
    ['milk', 'bread', 'nuts'],
    ['milk', 'bread'],
    ['milk', 'bread', 'apple'],
    ['milk', 'bread', 'apple']
]

# Convert dataset to one-hot encoded dataframe
te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)

# Apply Apriori algorithm
frequent_itemsets = apriori(df, min_support=0.6, use_colnames=True)

# Display frequent itemsets
print("Frequent Itemsets:")
print(frequent_itemsets)

# Generate association rules
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
print("\nAssociation Rules:")
print(rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']])
# Out:
# Frequent Itemsets:
#    support              itemsets
# 0      0.6               (apple)
# 1      1.0               (bread)
# 2      1.0                (milk)
# 3      0.6        (apple, bread)
# 4      0.6         (milk, apple)
# 5      1.0         (milk, bread)
# 6      0.6  (milk, apple, bread)
#
# Association Rules:
#        antecedents     consequents  support  confidence  lift
# 0          (apple)         (bread)      0.6         1.0   1.0
# 1          (bread)         (apple)      0.6         0.6   1.0
# 2           (milk)         (apple)      0.6         0.6   1.0
# 3          (apple)          (milk)      0.6         1.0   1.0
# 4           (milk)         (bread)      1.0         1.0   1.0
# 5          (bread)          (milk)      1.0         1.0   1.0
# 6    (milk, apple)         (bread)      0.6         1.0   1.0
# 7    (milk, bread)         (apple)      0.6         0.6   1.0
# 8   (apple, bread)          (milk)      0.6         1.0   1.0
# 9           (milk)  (apple, bread)      0.6         0.6   1.0
# 10         (apple)   (milk, bread)      0.6         1.0   1.0
# 11         (bread)   (milk, apple)      0.6         0.6   1.0
# C:\Users\kgadg\anaconda3\envs\Deep_Learning\Lib\site-packages\mlxtend\frequent_patterns\association_rules.py:186: RuntimeWarning: invalid value encountered in divide
#   cert_metric = np.where(certainty_denom == 0, 0, certainty_num / certainty_denom)

# %%
# Install mlxtend first (if not installed)
# !pip install mlxtend

import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# Load dataset
dataset = []
with open('Market_Basket_Optimisation.csv', 'r') as file:
    for line in file:
        items = [item.strip() for item in line.strip().split(',') if item.strip()]
        if items:
            dataset.append(items)

# Step 1: Transaction Encoding
te = TransactionEncoder()
te_data = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_data, columns=te.columns_)

# Step 2: Apply Apriori
frequent_itemsets = apriori(df, min_support=0.03, use_colnames=True)  # support >= 3%
print("Frequent Itemsets:\n", frequent_itemsets)

# Step 3: Generate Rules
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
print("\nAssociation Rules:")
print(rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']])
# Out:
# Frequent Itemsets:
#       support                            itemsets
# 0   0.033329                           (avocado)
# 1   0.033729                          (brownies)
# 2   0.087188                           (burgers)
# 3   0.030129                            (butter)
# 4   0.081056                              (cake)
# 5   0.046794                         (champagne)
# 6   0.059992                           (chicken)
# 7   0.163845                         (chocolate)
# 8   0.080389                           (cookies)
# 9   0.051060                       (cooking oil)
# 10  0.031862                    (cottage cheese)
# 11  0.179709                              (eggs)
# 12  0.079323                          (escalope)
# 13  0.170911                      (french fries)
# 14  0.043061                       (fresh bread)
# 15  0.063325                   (frozen smoothie)
# 16  0.095321                 (frozen vegetables)
# 17  0.052393                     (grated cheese)
# 18  0.132116                         (green tea)
# 19  0.098254                       (ground beef)
# 20  0.049460                     (herb & pepper)
# 21  0.047460                             (honey)
# 22  0.032396                          (hot dogs)
# 23  0.076523                    (low fat yogurt)
# 24  0.129583                              (milk)
# 25  0.238368                     (mineral water)
# 26  0.065858                         (olive oil)
# 27  0.095054                          (pancakes)
# 28  0.042528                            (salmon)
# 29  0.071457                            (shrimp)
# 30  0.050527                              (soup)
# 31  0.174110                         (spaghetti)
# 32  0.030396                      (tomato juice)
# 33  0.068391                          (tomatoes)
# 34  0.062525                            (turkey)
# 35  0.058526                  (whole wheat rice)
# 36  0.033196                   (chocolate, eggs)
# 37  0.034395           (chocolate, french fries)
# 38  0.032129                   (chocolate, milk)
# 39  0.052660          (chocolate, mineral water)
# 40  0.039195              (chocolate, spaghetti)
# 41  0.036395                (eggs, french fries)
# 42  0.030796                        (milk, eggs)
# 43  0.050927               (eggs, mineral water)
# 44  0.036528                   (spaghetti, eggs)
# 45  0.033729       (mineral water, french fries)
# 46  0.035729  (frozen vegetables, mineral water)
# 47  0.031063          (green tea, mineral water)
# 48  0.040928        (ground beef, mineral water)
# 49  0.039195            (spaghetti, ground beef)
# 50  0.047994               (milk, mineral water)
# 51  0.035462                   (milk, spaghetti)
# 52  0.033729           (pancakes, mineral water)
# 53  0.059725          (spaghetti, mineral water)
#
# Association Rules:
#             antecedents          consequents   support  confidence      lift
# 0           (chocolate)               (eggs)  0.033196    0.202604  1.127397
# 1                (eggs)          (chocolate)  0.033196    0.184718  1.127397
# 2           (chocolate)       (french fries)  0.034395    0.209927  1.228284
# 3        (french fries)          (chocolate)  0.034395    0.201248  1.228284
# 4           (chocolate)               (milk)  0.032129    0.196094  1.513276
# 5                (milk)          (chocolate)  0.032129    0.247942  1.513276
# 6           (chocolate)      (mineral water)  0.052660    0.321400  1.348332
# 7       (mineral water)          (chocolate)  0.052660    0.220917  1.348332
# 8           (chocolate)          (spaghetti)  0.039195    0.239219  1.373952
# 9           (spaghetti)          (chocolate)  0.039195    0.225115  1.373952
# 10               (eggs)       (french fries)  0.036395    0.202522  1.184961
# 11       (french fries)               (eggs)  0.036395    0.212949  1.184961
# 12               (milk)               (eggs)  0.030796    0.237654  1.322437
# 13               (eggs)               (milk)  0.030796    0.171365  1.322437
# 14               (eggs)      (mineral water)  0.050927    0.283383  1.188845
# 15      (mineral water)               (eggs)  0.050927    0.213647  1.188845
# 16          (spaghetti)               (eggs)  0.036528    0.209801  1.167446
# 17               (eggs)          (spaghetti)  0.036528    0.203264  1.167446
# 18  (frozen vegetables)      (mineral water)  0.035729    0.374825  1.572463
# 19      (mineral water)  (frozen vegetables)  0.035729    0.149888  1.572463
# 20        (ground beef)      (mineral water)  0.040928    0.416554  1.747522
# 21      (mineral water)        (ground beef)  0.040928    0.171700  1.747522
# 22          (spaghetti)        (ground beef)  0.039195    0.225115  2.291162
# 23        (ground beef)          (spaghetti)  0.039195    0.398915  2.291162
# 24               (milk)      (mineral water)  0.047994    0.370370  1.553774
# 25      (mineral water)               (milk)  0.047994    0.201342  1.553774
# 26               (milk)          (spaghetti)  0.035462    0.273663  1.571779
# 27          (spaghetti)               (milk)  0.035462    0.203675  1.571779
# 28           (pancakes)      (mineral water)  0.033729    0.354839  1.488616
# 29      (mineral water)           (pancakes)  0.033729    0.141499  1.488616
# 30          (spaghetti)      (mineral water)  0.059725    0.343032  1.439085
# 31      (mineral water)          (spaghetti)  0.059725    0.250559  1.439085

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# Load the dataset
df = pd.read_csv("Groceries_dataset.csv")

# Group transactions by Member_number and Date
grouped = df.groupby(['Member_number', 'Date'])['itemDescription'].apply(list)

# Convert transactions to list format
transactions = grouped.tolist()

# Apply Transaction Encoder
te = TransactionEncoder()
te_array = te.fit(transactions).transform(transactions)
df_encoded = pd.DataFrame(te_array, columns=te.columns_)

# Generate frequent itemsets
frequent_itemsets = apriori(df_encoded, min_support=0.02, use_colnames=True)

# Generate association rules
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.2)

# Filter rules further if needed
rules = rules[rules['lift'] > 1]

# Display top frequent itemsets
print("🔹 Frequent Itemsets:")
print(frequent_itemsets.sort_values(by='support', ascending=False).head(10))

print("\n🔹 Association Rules:")
print(rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']].sort_values(by='lift', ascending=False).head(10))
# Out:
# 🔹 Frequent Itemsets:
#      support            itemsets
# 36  0.157923        (whole milk)
# 24  0.122101  (other vegetables)
# 28  0.110005        (rolls/buns)
# 32  0.097106              (soda)
# 37  0.085879            (yogurt)
# 29  0.069572   (root vegetables)
# 33  0.067767    (tropical fruit)
# 4   0.060683     (bottled water)
# 30  0.060349           (sausage)
# 10  0.053131      (citrus fruit)
#
# 🔹 Association Rules:
# Empty DataFrame
# Columns: [antecedents, consequents, support, confidence, lift]
# Index: []
